# %% [markdown]
# ## Caso practico modelado
#
#
# ### 1.	Con el archivo de datos “Fish.csv” realice las siguientes actividades:
#
# * Ajuste un modelo de regresión lineal simple utilizando la variable “weight” y como
# explicativa la variable “Length3”, transformando las variables para que la relación lineal
# entre ellas sea válida. Interprete y discuta sus resultados, presentando tablas y gráficas
# para ilustrar sus hallazgos.
# * Ajuste un modelo similar al del apartado a), para cada una de las especies. ¿Son los
# coeficientes obtenidos estadísticamente diferentes entre todas las especies? En caso de
# que no lo sea, ¿cuáles especies muestran una relación longitud-peso distinta a las
# demás?
# * Calcule intervalos (bandas) de confianza para la recta ajustada y para las predicciones en
# cada uno de los casos, señalando la presencia o no de observaciones aberrantes
# (outliers).
#
#
# ### 2.	Repita el análisis de los puntos a) y b) y c), pero ahora utilizando la variable “Width” como respuesta y Height como variable explicativa
#
# NOTAS:
# Las figuras y tablas deben llevar un encabezado o pie (texto explicativo sobre su contenido.
# Vean algún artículo científico para saber cómo se cumple este requisito).
# La entrega de tablas y figuras tomadas directamente del software estadístico utilizado restarán
#
# Extracción de información:
#
# Responde el examen_sql_opcion_multiple.pdf que está anexo. Y comparte la información con las opciones correctas.
#
# Visualización de información:
#
# Genera un dashboard con base en tu análisis exploratorio de la información de la base de datos de fish.csv y expon lo que consideres importante para realizar.
# Considera que realizar una explicación de lo que expongas en cada uno de ellos.
